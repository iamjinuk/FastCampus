# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ---------------------

# %%
df = pd.read_csv("https://raw.githubusercontent.com/yoonkt200/FastCampusDataset/master/BostonHousing2.csv")
df.head()
# Out:
#          TOWN     LON      LAT  CMEDV     CRIM    ZN  INDUS  CHAS    NOX  \
# 0      Nahant -70.955  42.2550   24.0  0.00632  18.0   2.31     0  0.538
# 1  Swampscott -70.950  42.2875   21.6  0.02731   0.0   7.07     0  0.469
# 2  Swampscott -70.936  42.2830   34.7  0.02729   0.0   7.07     0  0.469
# 3  Marblehead -70.928  42.2930   33.4  0.03237   0.0   2.18     0  0.458
# 4  Marblehead -70.922  42.2980   36.2  0.06905   0.0   2.18     0  0.458
#
#       RM   AGE     DIS  RAD  TAX  PTRATIO       B  LSTAT
# 0  6.575  65.2  4.0900    1  296     15.3  396.90   4.98
# 1  6.421  78.9  4.9671    2  242     17.8  396.90   9.14
# 2  7.185  61.1  4.9671    2  242     17.8  392.83   4.03
# 3  6.998  45.8  6.0622    3  222     18.7  394.63   2.94
# 4  7.147  54.2  6.0622    3  222     18.7  396.90   5.33

# %% [markdown]
# ### Feature Discription

# %% [markdown]
# - TOWN : 지역이름
# - LON, LAT : 위도, 경도 정보
# - *CMEDV : 해당 지역의 집값(중간값)
# - CRIM : 근방 범죄율
# - ZN : 주택지 비율
# - INDUS : 상업적 비즈니스에 활용되지 않는 농지 면적
# - CHAS : 경계선에 강이 있는지 여부
# - NOX : 산화질소 농도
# - RM : 자택당 평균 방 갯수
# - AGE : 1940년 이전에 건성된 비율
# - DIS : 5개의 보스턴 고용센터와의 거리에 따른 가중치 부여
# - RAD : radial고속도로와의 접근성 지수
# - TAX : 10000달러당 재산세
# - PTRATIO : 지역별 학생-교사 비율
# - B : 지역의 흑인 지수 (10000(B-0.63)^2), B는 흑인 비율
# - LSTAT : 빈곤측의 비율

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (506, 17)

# %%
df.isnull().sum()
# Out:
# TOWN       0
# LON        0
# LAT        0
# CMEDV      0
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   TOWN     506 non-null    object
#  1   LON      506 non-null    float64
#  2   LAT      506 non-null    float64
#  3   CMEDV    506 non-null    float64
#  4   CRIM     506 non-null    float64
#  5   ZN       506 non-null    float64
#  6   INDUS    506 non-null    float64
#  7   CHAS     506 non-null    int64
#  8   NOX      506 non-null    float64
#  9   RM       506 non-null    float64
#  10  AGE      506 non-null    float64
#  11  DIS      506 non-null    float64
#  12  RAD      506 non-null    int64
#  13  TAX      506 non-null    int64
#  14  PTRATIO  506 non-null    float64
#  15  B        506 non-null    float64
#  16  LSTAT    506 non-null    float64
# dtypes: float64(13), int64(3), object(1)
# memory usage: 67.3+ KB

# %% [markdown]
# ## ▼'CMEDW' 피처 탐색

# %%
df['CMEDV'].describe()
# Out:
# count    506.000000
# mean      22.528854
# std        9.182176
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: CMEDV, dtype: float64

# %%
# 매매가 분포 확인
df['CMEDV'].hist(bins=50)

# %%
df.boxplot(column=['CMEDV'])
# 동일 df['CMEDV'].plot.box()

# %% [markdown]
# ---------------------

# %% [markdown]
# ## ▼회귀 분석을 위한 설명 변수 탐색

# %%
numerical_columns = df[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 
                     'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 
                     'B', 'LSTAT']]

numerical_columns.hist(figsize=(16,20))
plt.show()

# %% [markdown]
# ## ▼ 설명 변수들의 상관관계 탐색

# %%
cols = df[['CMEDV','CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 
          'TAX', 'PTRATIO', 'B', 'LSTAT']]

# %%
#  이 corr 로 heatmap 그리면 오류 남
corr = cols.corr(method='pearson')
corr
# Out:
#             CMEDV      CRIM        ZN     INDUS      CHAS       NOX        RM  \
# CMEDV    1.000000 -0.389582  0.360386 -0.484754  0.175663 -0.429300  0.696304
# CRIM    -0.389582  1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN       0.360386 -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS   -0.484754  0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS     0.175663 -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX     -0.429300  0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM       0.696304 -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE     -0.377999  0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS      0.249315 -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD     -0.384766  0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX     -0.471979  0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# ...

# %%
cols = ['CMEDV', 'CRIM', 'ZN', 'INDUS', 
        'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 
        'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

corr = df[cols].corr(method='pearson')
corr
# Out:
#             CMEDV      CRIM        ZN     INDUS      CHAS       NOX        RM  \
# CMEDV    1.000000 -0.389582  0.360386 -0.484754  0.175663 -0.429300  0.696304
# CRIM    -0.389582  1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN       0.360386 -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS   -0.484754  0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS     0.175663 -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX     -0.429300  0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM       0.696304 -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE     -0.377999  0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS      0.249315 -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD     -0.384766  0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX     -0.471979  0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# ...

# %%
plt.figure(figsize=(20,20))
sns.set(font_scale=1.0)
sns.heatmap(data=corr, annot=True, fmt='2f', yticklabels=cols, xticklabels=cols)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ▼ 상관 관계가 높았던 두 변수들에 대해 각각의 상관관계 분포 파악하기

# %%
plt.plot('RM', 'CMEDV', data=df, linestyle='none', marker='o', markersize=5, color='blue', alpha=0.5)
plt.title('scatter plot')
plt.xlabel('RM')
plt.xlabel('CM')

# %%
plt.plot('RM', 'LSTAT', data=df, linestyle='none', marker='o', markersize=5, color='blue', alpha=0.5)
plt.title('scatter plot')
plt.xlabel('LSTAT')
plt.xlabel('CM')
plt.show()

# %% [markdown]
# ## ▼ 지역별 탐색

# %%
df['TOWN'].value_counts()
# Out:
# Cambridge            30
# Boston Savin Hill    23
# Lynn                 22
# Boston Roxbury       19
# Newton               18
#                      ..
# Duxbury               1
# Cohasset              1
# Sherborn              1
# Manchester            1
# Norfolk               1
# Name: TOWN, Length: 92, dtype: int64

# %%
df['TOWN'].value_counts().hist(bins=50)

# %% [markdown]
# ### 지역별 부동산 가격

# %%
plt.figure(figsize=(16,20))
sns.boxplot(x='CMEDV', y='TOWN', data=df)

# %% [markdown]
# ### 지역별 범죄율

# %%
plt.figure(figsize=(16,20))
sns.boxplot(x='CRIM', y='TOWN', data=df)

# %% [markdown]
# ----------------

# %% [markdown]
# # 집값 예측 분석 : 회귀 분석

# %% [markdown]
# feature standardization - 피처 스케일링
#
# feature 들의 표준화 작업이 필요하다.
# - 이유 : 어떤 feature의 범위는 0~10이고, 어떤 feature는 0~100일 때, feature들 간에 단위 불일치 발생

# %% [markdown]
# ### ▼ feature 표준화

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scale_columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
df[scale_columns] = scaler.fit_transform(df[scale_columns])  
# fit_transform 중요!

# %%
df.head()
# Out:
#          TOWN     LON      LAT  CMEDV     CRIM    ZN  INDUS  CHAS    NOX  \
# 0      Nahant -70.955  42.2550   24.0  0.00632  18.0   2.31     0  0.538
# 1  Swampscott -70.950  42.2875   21.6  0.02731   0.0   7.07     0  0.469
# 2  Swampscott -70.936  42.2830   34.7  0.02729   0.0   7.07     0  0.469
# 3  Marblehead -70.928  42.2930   33.4  0.03237   0.0   2.18     0  0.458
# 4  Marblehead -70.922  42.2980   36.2  0.06905   0.0   2.18     0  0.458
#
#       RM   AGE     DIS  RAD  TAX  PTRATIO       B  LSTAT
# 0  6.575  65.2  4.0900    1  296     15.3  396.90   4.98
# 1  6.421  78.9  4.9671    2  242     17.8  396.90   9.14
# 2  7.185  61.1  4.9671    2  242     17.8  392.83   4.03
# 3  6.998  45.8  6.0622    3  222     18.7  394.63   2.94
# 4  7.147  54.2  6.0622    3  222     18.7  396.90   5.33

# %%
df.head()
# Out:
#          TOWN     LON      LAT  CMEDV      CRIM        ZN     INDUS      CHAS  \
# 0      Nahant -70.955  42.2550   24.0 -0.419782  0.284830 -1.287909 -0.272599
# 1  Swampscott -70.950  42.2875   21.6 -0.417339 -0.487722 -0.593381 -0.272599
# 2  Swampscott -70.936  42.2830   34.7 -0.417342 -0.487722 -0.593381 -0.272599
# 3  Marblehead -70.928  42.2930   33.4 -0.416750 -0.487722 -1.306878 -0.272599
# 4  Marblehead -70.922  42.2980   36.2 -0.412482 -0.487722 -1.306878 -0.272599
#
#         NOX        RM       AGE       DIS       RAD       TAX   PTRATIO  \
# 0 -0.144217  0.413672 -0.120013  0.140214 -0.982843 -0.666608 -1.459000
# 1 -0.740262  0.194274  0.367166  0.557160 -0.867883 -0.987329 -0.303094
# 2 -0.740262  1.282714 -0.265812  0.557160 -0.867883 -0.987329 -0.303094
# 3 -0.835284  1.016303 -0.809889  1.077737 -0.752922 -1.106115  0.113032
# 4 -0.835284  1.228577 -0.511180  1.077737 -0.752922 -1.106115  0.113032
#
#           B     LSTAT
# 0  0.441052 -1.075562
# ...

# %% [markdown]
# ### ▼ 데이터셋 분리

# %%
from sklearn.model_selection import train_test_split

X = df[scale_columns]
Y = df['CMEDV']

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=33)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (404, 13)
# (102, 13)
# (404,)
# (102,)

# %% [markdown]
# ## 회귀 분석 모델 학습

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
LR = linear_model.LinearRegression()
model = LR.fit(X_trian, Y_trian)

# %%
# 학습 결과 확인
# 13개 변수들에 대한 y값

print(LR.coef_)
# Out:
# [-0.95549078  1.18690662  0.22303997  0.76659756 -1.78400866  2.83991455
#  -0.05556583 -3.28406695  2.84479571 -2.33740727 -1.77815381  0.79772973
#  -4.17382086]

# %%
plt.figure(figsize=(12,16))

coefs = LR.coef_.tolist()
coefs_series = pd.Series(coefs)

# %%
ax = coefs_series.plot.barh(figsize=(12,16))
x_labels = scale_columns
ax.set_title('feature coef graph')
ax.set_xlabel('coef')
ax.set_ylabel('x features')
ax.set_yticklabels(x_labels)
plt.show()

# %% [markdown]
# ----------------------

# %% [markdown]
# ## 학습결과 해석

# %% [markdown]
# ### ▼ R2 score

# %%
print(model.score(X_train, Y_train))
# Out:
# 0.7490284664199387

# %%
print(model.score(X_test, Y_test))
# Out:
# 0.7009342135321549

# %% [markdown]
# ### ▼ RMSE score

# %%
y_predictions = LR.predict(X_train)
print(sqrt(mean_squared_error(Y_train, y_predictions)))

y_predictions = LR.predict(X_test)
print(sqrt(mean_squared_error(Y_test, y_predictions)))
# Out:
# 4.672162734008589
# 4.614951784913311

# %% [markdown]
# ### ▼ 피처유의성 검정

# %%
import statsmodels.api as sm

X_train = sm.add_constant(X_train)
model = sm.OLS(Y_train, X_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  CMEDV   R-squared:                       0.749
# Model:                            OLS   Adj. R-squared:                  0.741
# Method:                 Least Squares   F-statistic:                     89.54
# Date:                Fri, 01 Jan 2021   Prob (F-statistic):          2.61e-108
# Time:                        22:02:22   Log-Likelihood:                -1196.1
# No. Observations:                 404   AIC:                             2420.
# Df Residuals:                     390   BIC:                             2476.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         22.4800      0.238     94.635      0.000      22.013      22.947
# ...

# %% [markdown]
# -----------------

# %% [markdown]
# INDUS와 AGE 변수는 P-value가 0.05이상의 값을 가지므로, 해당 모델에 유효하지 않은 feature라고 판단.
